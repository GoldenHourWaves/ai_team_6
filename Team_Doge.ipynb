# %%
print("Team Doge co-cording python page")

print("pull, commit, push test!")

print("get clone 하세요!")

print("added a branch as junwoo-dev by junwoo")

print("uv.lock renewal")
# Out:
# Team Doge co-cording python page
# pull, commit, push test!
# get clone 하세요!
# added a branch as junwoo-dev by junwoo
# uv.lock renewal

# %%
import pandas as pd
import numpy as np
print("환경 세팅 완료!")
# Out:
# 환경 세팅 완료!

# %%
import numpy as np
import sys

try:
    # 1. 버전 확인
    print(f"Numpy 버전: {np.__version__}")
    print(f"Python 경로: {sys.executable}")
    
    # 2. 간단한 연산 테스트 (에러가 나면 여기서 멈춥니다)
    arr = np.array([1, 2, 3, 4, 5])
    print(f"배열 생성 테스트: {arr}")
    print(f"평균값 계산 테스트: {np.mean(arr)}")
    
    # 3. 행렬 연산 테스트 (C 확장 모듈 로드 확인)
    matrix = np.ones((3, 3))
    dot_product = np.dot(matrix, matrix)
    print("행렬 연산 성공!")
    
    print("\n✅ 모든 테스트 통과! Numpy가 완벽하게 설치되었습니다.")

except Exception as e:
    print(f"\n❌ 아직 문제가 남아있습니다: \n{e}")
# Out:
# Numpy 버전: 2.4.1
# Python 경로: c:\junwoo\AI_Project_01_Team6\.venv\Scripts\python.exe
# 배열 생성 테스트: [1 2 3 4 5]
# 평균값 계산 테스트: 3.0
# 행렬 연산 성공!
#
# ✅ 모든 테스트 통과! Numpy가 완벽하게 설치되었습니다.

# %%
print("test after git pull origin main")
# Out:
# test after git pull origin main
